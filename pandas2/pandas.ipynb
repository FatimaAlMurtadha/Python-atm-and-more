# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
print()
print(" Series vs DataFrame")
print("="*50)
print()

age = pd.Series([11,22,33])
print("A series:   ", age)
# Out:
#  Series vs DataFrame
# ==================================================
#
# A series:    0    11
# 1    22
# 2    33
# dtype: int64

# %%
# An object
age = pd.Series([11, "same", False])
age
# Out:
# 0       11
# 1     same
# 2    False
# dtype: object

# %%
age = pd.Series([11, "same", False], index=['a','b','c'])
age
# Out:
# a       11
# b     same
# c    False
# dtype: object

# %%
# data frame
studentInfo = pd.DataFrame({
    'name':["sama", "Ahmed","Omer"], # string
    'age':[21,22,23], # int
    'isGraduated':[True,True,False] # bool
    
}, index=['a','b','c'])
studentInfo
# Out:
#     name  age  isGraduated
# a   sama   21         True
# b  Ahmed   22         True
# c   Omer   23        False

# %%
# File -> Data
df = pd.read_csv('./FINAL_DATASET.csv')
df
# Out:
#       image_id                                          image_url label  \
# 0            1  https://images.unsplash.com/photo-172422561835...  REAL
# 1            2  https://images.unsplash.com/photo-172422561873...  REAL
# 2            3  https://images.unsplash.com/photo-172422561834...  REAL
# 3            4  https://images.unsplash.com/photo-172422561855...  REAL
# 4            5  https://images.unsplash.com/photo-172422561823...  REAL
# ...        ...                                                ...   ...
# 6552      6553            https://api.multiavatar.com/face996.jpg  FAKE
# 6553      6554            https://api.multiavatar.com/face997.jpg  FAKE
# 6554      6555            https://api.multiavatar.com/face998.jpg  FAKE
# 6555      6556            https://api.multiavatar.com/face999.jpg  FAKE
# 6556      6557           https://api.multiavatar.com/face1000.jpg  FAKE
#
#       label_numeric      category   gender age_group       source fake_method  \
# 0                 1     Authentic   Female     18-25     Unsplash         NaN
# 1                 1     Authentic     Male       50+     Unsplash         NaN
# 2                 1     Authentic   Female     36-50     Unsplash         NaN
# 3                 1     Authentic   Female     26-35     Unsplash         NaN
# 4                 1     Authentic     Male     36-50     Unsplash         NaN
# ...             ...           ...      ...       ...          ...         ...
# 6552              0  AI Generated  Unknown     18-25  MultiSource   StyleGAN3
# 6553              0  AI Generated  Unknown       50+  MultiSource   StyleGAN3
# 6554              0  AI Generated  Unknown     18-25  MultiSource   StyleGAN3
# 6555              0  AI Generated  Unknown     26-35  MultiSource   StyleGAN3
# 6556              0  AI Generated  Unknown     36-50  MultiSource   StyleGAN3
#
#      image_quality resolution  confidence_score detection_difficulty  \
# 0             High  1080x1080              0.96                 Easy
# 1             High  1080x1080              0.97                 Easy
# 2             High  1080x1080              0.95                 Easy
# 3             High  1080x1080              0.89                 Easy
# 4             High  1080x1080              0.86                 Easy
# ...            ...        ...               ...                  ...
# 6552          High  1024x1024              0.85                 Hard
# 6553          High  1024x1024              0.96                 Hard
# 6554          High  1024x1024              0.91               Medium
# 6555          High  1024x1024              0.86               Medium
# 6556        Medium  1024x1024              0.93                 Hard
#
#      dataset_split date_collected version  year
# 0            train     2026-04-24    v2.0  2026
# 1            train     2026-04-04    v2.0  2026
# 2             test     2026-02-07    v2.0  2026
# 3            train     2026-02-20    v2.0  2026
# 4            train     2026-04-12    v2.0  2026
# ...            ...            ...     ...   ...
# 6552         train     2026-01-12    v2.0  2026
# 6553         train     2026-01-07    v2.0  2026
# 6554         train     2026-04-24    v2.0  2026
# 6555         train     2026-01-24    v2.0  2026
# 6556           val     2026-03-12    v2.0  2026
#
# [6557 rows x 17 columns]

# %%
# A column
print(df['category'])
# Out:
# 0          Authentic
# 1          Authentic
# 2          Authentic
# 3          Authentic
# 4          Authentic
#             ...
# 6552    AI Generated
# 6553    AI Generated
# 6554    AI Generated
# 6555    AI Generated
# 6556    AI Generated
# Name: category, Length: 6557, dtype: str

# %%
# More than 1 column
print(df[['category','gender']])
# Out:
#           category   gender
# 0        Authentic   Female
# 1        Authentic     Male
# 2        Authentic   Female
# 3        Authentic   Female
# 4        Authentic     Male
# ...            ...      ...
# 6552  AI Generated  Unknown
# 6553  AI Generated  Unknown
# 6554  AI Generated  Unknown
# 6555  AI Generated  Unknown
# 6556  AI Generated  Unknown
#
# [6557 rows x 2 columns]

# %%
# Row [n] iloc takes the index ignoring the naming
df.iloc[10]
# Out:
# image_id                                                               11
# image_url               https://images.unsplash.com/photo-172422561812...
# label                                                                REAL
# label_numeric                                                           1
# category                                                        Authentic
# gender                                                            Unknown
# age_group                                                           26-35
# source                                                           Unsplash
# fake_method                                                           NaN
# image_quality                                                        High
# resolution                                                      1080x1080
# confidence_score                                                     0.97
# detection_difficulty                                                 Easy
# dataset_split                                                       train
# date_collected                                                 2026-02-13
# version                                                              v2.0
# year                                                                 2026
# Name: 10, dtype: object

# %%
# index depending on the real index name  
# loc [ R. labelName]
df.loc[10]
# Out:
# image_id                                                               11
# image_url               https://images.unsplash.com/photo-172422561812...
# label                                                                REAL
# label_numeric                                                           1
# category                                                        Authentic
# gender                                                            Unknown
# age_group                                                           26-35
# source                                                           Unsplash
# fake_method                                                           NaN
# image_quality                                                        High
# resolution                                                      1080x1080
# confidence_score                                                     0.97
# detection_difficulty                                                 Easy
# dataset_split                                                       train
# date_collected                                                 2026-02-13
# version                                                              v2.0
# year                                                                 2026
# Name: 10, dtype: object

# %%
# iloc [R,C]
df.iloc[0,5]
# Out:
# 'Female'

# %%
# All first n elements / ending not included
df.iloc[3:10]
# Out:
#    image_id                                          image_url label  \
# 3         4  https://images.unsplash.com/photo-172422561855...  REAL
# 4         5  https://images.unsplash.com/photo-172422561823...  REAL
# 5         6  https://images.unsplash.com/photo-172422561869...  REAL
# 6         7  https://images.unsplash.com/photo-165740366923...  REAL
# 7         8  https://images.unsplash.com/photo-172422561885...  REAL
# 8         9  https://images.unsplash.com/photo-172422561833...  REAL
# 9        10  https://images.unsplash.com/photo-172422561873...  REAL
#
#    label_numeric   category   gender age_group    source fake_method  \
# 3              1  Authentic   Female     26-35  Unsplash         NaN
# 4              1  Authentic     Male     36-50  Unsplash         NaN
# 5              1  Authentic  Unknown       50+  Unsplash         NaN
# 6              1  Authentic     Male     26-35  Unsplash         NaN
# 7              1  Authentic  Unknown     18-25  Unsplash         NaN
# 8              1  Authentic     Male     26-35  Unsplash         NaN
# 9              1  Authentic  Unknown     26-35  Unsplash         NaN
#
#   image_quality resolution  confidence_score detection_difficulty  \
# 3          High  1080x1080              0.89                 Easy
# 4          High  1080x1080              0.86                 Easy
# 5          High  1080x1080              0.97                 Easy
# 6        Medium  1080x1080              0.87                 Easy
# 7          High  1080x1080              0.88                 Easy
# 8          High  1080x1080              0.94                 Easy
# 9          High  1080x1080              0.88                 Easy
#
#   dataset_split date_collected version  year
# 3         train     2026-02-20    v2.0  2026
# 4         train     2026-04-12    v2.0  2026
# 5           val     2026-04-23    v2.0  2026
# 6          test     2026-03-09    v2.0  2026
# 7           val     2026-04-05    v2.0  2026
# 8         train     2026-02-26    v2.0  2026
# 9         train     2026-02-09    v2.0  2026

# %%
# Condition - filter df[df[condition]]
df[df['confidence_score'] > 0.89]
# Out:
#       image_id                                          image_url label  \
# 0            1  https://images.unsplash.com/photo-172422561835...  REAL
# 1            2  https://images.unsplash.com/photo-172422561873...  REAL
# 2            3  https://images.unsplash.com/photo-172422561834...  REAL
# 5            6  https://images.unsplash.com/photo-172422561869...  REAL
# 8            9  https://images.unsplash.com/photo-172422561833...  REAL
# ...        ...                                                ...   ...
# 6548      6549            https://api.multiavatar.com/face992.jpg  FAKE
# 6549      6550            https://api.multiavatar.com/face993.jpg  FAKE
# 6553      6554            https://api.multiavatar.com/face997.jpg  FAKE
# 6554      6555            https://api.multiavatar.com/face998.jpg  FAKE
# 6556      6557           https://api.multiavatar.com/face1000.jpg  FAKE
#
#       label_numeric      category   gender age_group       source fake_method  \
# 0                 1     Authentic   Female     18-25     Unsplash         NaN
# 1                 1     Authentic     Male       50+     Unsplash         NaN
# 2                 1     Authentic   Female     36-50     Unsplash         NaN
# 5                 1     Authentic  Unknown       50+     Unsplash         NaN
# 8                 1     Authentic     Male     26-35     Unsplash         NaN
# ...             ...           ...      ...       ...          ...         ...
# 6548              0  AI Generated  Unknown     36-50  MultiSource   StyleGAN3
# 6549              0  AI Generated  Unknown       50+  MultiSource   StyleGAN3
# 6553              0  AI Generated  Unknown       50+  MultiSource   StyleGAN3
# 6554              0  AI Generated  Unknown     18-25  MultiSource   StyleGAN3
# 6556              0  AI Generated  Unknown     36-50  MultiSource   StyleGAN3
#
#      image_quality resolution  confidence_score detection_difficulty  \
# 0             High  1080x1080              0.96                 Easy
# 1             High  1080x1080              0.97                 Easy
# 2             High  1080x1080              0.95                 Easy
# 5             High  1080x1080              0.97                 Easy
# 8             High  1080x1080              0.94                 Easy
# ...            ...        ...               ...                  ...
# 6548        Medium  1024x1024              0.96               Medium
# 6549        Medium  1024x1024              0.97               Medium
# 6553          High  1024x1024              0.96                 Hard
# 6554          High  1024x1024              0.91               Medium
# 6556        Medium  1024x1024              0.93                 Hard
#
#      dataset_split date_collected version  year
# 0            train     2026-04-24    v2.0  2026
# 1            train     2026-04-04    v2.0  2026
# 2             test     2026-02-07    v2.0  2026
# 5              val     2026-04-23    v2.0  2026
# 8            train     2026-02-26    v2.0  2026
# ...            ...            ...     ...   ...
# 6548         train     2026-04-27    v2.0  2026
# 6549         train     2026-04-06    v2.0  2026
# 6553         train     2026-01-07    v2.0  2026
# 6554         train     2026-04-24    v2.0  2026
# 6556           val     2026-03-12    v2.0  2026
#
# [3714 rows x 17 columns]

# %%
# at == loc [R, labelName]
# iat == iloc [R, C ]
# at + iat faster 
df.iat[0,5]
# Out:
# 'Female'

# %%
# Index range (start, stop, step) Rows
df.index
# Out:
# RangeIndex(start=0, stop=6557, step=1)

# %%
# Columns name dtype= "?"
df.columns
# Out:
# Index(['image_id', 'image_url', 'label', 'label_numeric', 'category', 'gender',
#        'age_group', 'source', 'fake_method', 'image_quality', 'resolution',
#        'confidence_score', 'detection_difficulty', 'dataset_split',
#        'date_collected', 'version', 'year'],
#       dtype='str')

# %%
# Array values
df.values
# Out:
# array([[1,
#         'https://images.unsplash.com/photo-1724225618359-a1d2763326f9?crop=entropy&cs=tinysrgb&fit=max&fm=jpg&ixid=M3w5NDQwMTV8MHwxfHNlYXJjaHwxfHxodW1hbiUyMGZhY2UlMjBwb3J0cmFpdHxlbnwwfHx8fDE3NzgwNjQ2ODd8MA&ixlib=rb-4.1.0&q=80&w=1080',
#         'REAL', ..., '2026-04-24', 'v2.0', 2026],
#        [2,
#         'https://images.unsplash.com/photo-1724225618735-075be4f96a63?crop=entropy&cs=tinysrgb&fit=max&fm=jpg&ixid=M3w5NDQwMTV8MHwxfHNlYXJjaHwyfHxodW1hbiUyMGZhY2UlMjBwb3J0cmFpdHxlbnwwfHx8fDE3NzgwNjQ2ODd8MA&ixlib=rb-4.1.0&q=80&w=1080',
#         'REAL', ..., '2026-04-04', 'v2.0', 2026],
#        [3,
#         'https://images.unsplash.com/photo-1724225618348-636d316ef39b?crop=entropy&cs=tinysrgb&fit=max&fm=jpg&ixid=M3w5NDQwMTV8MHwxfHNlYXJjaHwzfHxodW1hbiUyMGZhY2UlMjBwb3J0cmFpdHxlbnwwfHx8fDE3NzgwNjQ2ODd8MA&ixlib=rb-4.1.0&q=80&w=1080',
#         'REAL', ..., '2026-02-07', 'v2.0', 2026],
#        ...,
#        [6555, 'https://api.multiavatar.com/face998.jpg', 'FAKE', ...,
#         '2026-04-24', 'v2.0', 2026],
#        [6556, 'https://api.multiavatar.com/face999.jpg', 'FAKE', ...,
#         '2026-01-24', 'v2.0', 2026],
#        [6557, 'https://api.multiavatar.com/face1000.jpg', 'FAKE', ...,
#         '2026-03-12', 'v2.0', 2026]], shape=(6557, 17), dtype=object)

# %%
# Data type
df.dtypes
# Out:
# image_id                  int64
# image_url                   str
# label                       str
# label_numeric             int64
# category                    str
# gender                      str
# age_group                   str
# source                      str
# fake_method                 str
# image_quality               str
# resolution                  str
# confidence_score        float64
# detection_difficulty        str
# dataset_split               str
# date_collected              str
# version                     str
# year                      int64
# dtype: object

# %%
# (R,C) (6557,17)
df.shape
# Out:
# (6557, 17)

# %%
# Data frame dim  
# 4 dim means 4 different tables (R,C) inside on array
df.ndim
# Out:
# 2

# %%
# sum(R.C)
df.size
# Out:
# 111469

# %%
df.empty
# Out:
# False

# %%
# transpose 
df.T
# Out:
#                                                                    0     \
# image_id                                                              1
# image_url             https://images.unsplash.com/photo-172422561835...
# label                                                              REAL
# label_numeric                                                         1
# category                                                      Authentic
# gender                                                           Female
# age_group                                                         18-25
# source                                                         Unsplash
# fake_method                                                         NaN
# image_quality                                                      High
# resolution                                                    1080x1080
# confidence_score                                                   0.96
# detection_difficulty                                               Easy
# dataset_split                                                     train
# date_collected                                               2026-04-24
# version                                                            v2.0
# year                                                               2026
#
#                                                                    1     \
# image_id                                                              2
# image_url             https://images.unsplash.com/photo-172422561873...
# label                                                              REAL
# label_numeric                                                         1
# category                                                      Authentic
# gender                                                             Male
# age_group                                                           50+
# source                                                         Unsplash
# fake_method                                                         NaN
# image_quality                                                      High
# resolution                                                    1080x1080
# confidence_score                                                   0.97
# detection_difficulty                                               Easy
# dataset_split                                                     train
# date_collected                                               2026-04-04
# version                                                            v2.0
# year                                                               2026
#
#                                                                    2     \
# image_id                                                              3
# image_url             https://images.unsplash.com/photo-172422561834...
# label                                                              REAL
# label_numeric                                                         1
# category                                                      Authentic
# gender                                                           Female
# age_group                                                         36-50
# source                                                         Unsplash
# fake_method                                                         NaN
# image_quality                                                      High
# resolution                                                    1080x1080
# confidence_score                                                   0.95
# detection_difficulty                                               Easy
# dataset_split                                                      test
# date_collected                                               2026-02-07
# version                                                            v2.0
# year                                                               2026
#
#                                                                    3     \
# image_id                                                              4
# image_url             https://images.unsplash.com/photo-172422561855...
# label                                                              REAL
# label_numeric                                                         1
# category                                                      Authentic
# gender                                                           Female
# age_group                                                         26-35
# source                                                         Unsplash
# fake_method                                                         NaN
# image_quality                                                      High
# resolution                                                    1080x1080
# confidence_score                                                   0.89
# detection_difficulty                                               Easy
# dataset_split                                                     train
# date_collected                                               2026-02-20
# version                                                            v2.0
# year                                                               2026
#
#                                                                    4     \
# image_id                                                              5
# image_url             https://images.unsplash.com/photo-172422561823...
# label                                                              REAL
# label_numeric                                                         1
# category                                                      Authentic
# gender                                                             Male
# age_group                                                         36-50
# source                                                         Unsplash
# fake_method                                                         NaN
# image_quality                                                      High
# resolution                                                    1080x1080
# confidence_score                                                   0.86
# detection_difficulty                                               Easy
# dataset_split                                                     train
# date_collected                                               2026-04-12
# version                                                            v2.0
# year                                                               2026
#
#                                                                    5     \
# image_id                                                              6
# image_url             https://images.unsplash.com/photo-172422561869...
# label                                                              REAL
# label_numeric                                                         1
# category                                                      Authentic
# gender                                                          Unknown
# age_group                                                           50+
# source                                                         Unsplash
# fake_method                                                         NaN
# image_quality                                                      High
# resolution                                                    1080x1080
# confidence_score                                                   0.97
# detection_difficulty                                               Easy
# dataset_split                                                       val
# date_collected                                               2026-04-23
# version                                                            v2.0
# year                                                               2026
#
#                                                                    6     \
# image_id                                                              7
# image_url             https://images.unsplash.com/photo-165740366923...
# label                                                              REAL
# label_numeric                                                         1
# category                                                      Authentic
# gender                                                             Male
# age_group                                                         26-35
# source                                                         Unsplash
# fake_method                                                         NaN
# image_quality                                                    Medium
# resolution                                                    1080x1080
# confidence_score                                                   0.87
# detection_difficulty                                               Easy
# dataset_split                                                      test
# date_collected                                               2026-03-09
# version                                                            v2.0
# year                                                               2026
#
#                                                                    7     \
# image_id                                                              8
# image_url             https://images.unsplash.com/photo-172422561885...
# label                                                              REAL
# label_numeric                                                         1
# category                                                      Authentic
# gender                                                          Unknown
# age_group                                                         18-25
# source                                                         Unsplash
# fake_method                                                         NaN
# image_quality                                                      High
# resolution                                                    1080x1080
# confidence_score                                                   0.88
# detection_difficulty                                               Easy
# dataset_split                                                       val
# date_collected                                               2026-04-05
# version                                                            v2.0
# year                                                               2026
#
#                                                                    8     \
# image_id                                                              9
# image_url             https://images.unsplash.com/photo-172422561833...
# label                                                              REAL
# label_numeric                                                         1
# category                                                      Authentic
# gender                                                             Male
# age_group                                                         26-35
# source                                                         Unsplash
# fake_method                                                         NaN
# image_quality                                                      High
# resolution                                                    1080x1080
# confidence_score                                                   0.94
# detection_difficulty                                               Easy
# dataset_split                                                     train
# date_collected                                               2026-02-26
# version                                                            v2.0
# year                                                               2026
#
#                                                                    9     ...  \
# image_id                                                             10  ...
# image_url             https://images.unsplash.com/photo-172422561873...  ...
# label                                                              REAL  ...
# label_numeric                                                         1  ...
# category                                                      Authentic  ...
# gender                                                          Unknown  ...
# age_group                                                         26-35  ...
# source                                                         Unsplash  ...
# fake_method                                                         NaN  ...
# image_quality                                                      High  ...
# resolution                                                    1080x1080  ...
# confidence_score                                                   0.88  ...
# detection_difficulty                                               Easy  ...
# dataset_split                                                     train  ...
# date_collected                                               2026-02-09  ...
# version                                                            v2.0  ...
# year                                                               2026  ...
#
#                                                          6547  \
# image_id                                                 6548
# image_url             https://api.multiavatar.com/face991.jpg
# label                                                    FAKE
# label_numeric                                               0
# category                                         AI Generated
# gender                                                Unknown
# age_group                                               26-35
# source                                            MultiSource
# fake_method                                         StyleGAN3
# image_quality                                            High
# resolution                                          1024x1024
# confidence_score                                         0.98
# detection_difficulty                                   Medium
# dataset_split                                            test
# date_collected                                     2026-02-07
# version                                                  v2.0
# year                                                     2026
#
#                                                          6548  \
# image_id                                                 6549
# image_url             https://api.multiavatar.com/face992.jpg
# label                                                    FAKE
# label_numeric                                               0
# category                                         AI Generated
# gender                                                Unknown
# age_group                                               36-50
# source                                            MultiSource
# fake_method                                         StyleGAN3
# image_quality                                          Medium
# resolution                                          1024x1024
# confidence_score                                         0.96
# detection_difficulty                                   Medium
# dataset_split                                           train
# date_collected                                     2026-04-27
# version                                                  v2.0
# year                                                     2026
#
#                                                          6549  \
# image_id                                                 6550
# image_url             https://api.multiavatar.com/face993.jpg
# label                                                    FAKE
# label_numeric                                               0
# category                                         AI Generated
# gender                                                Unknown
# age_group                                                 50+
# source                                            MultiSource
# fake_method                                         StyleGAN3
# image_quality                                          Medium
# resolution                                          1024x1024
# confidence_score                                         0.97
# detection_difficulty                                   Medium
# dataset_split                                           train
# date_collected                                     2026-04-06
# version                                                  v2.0
# year                                                     2026
#
#                                                          6550  \
# image_id                                                 6551
# image_url             https://api.multiavatar.com/face994.jpg
# label                                                    FAKE
# label_numeric                                               0
# category                                         AI Generated
# gender                                                Unknown
# age_group                                               26-35
# source                                            MultiSource
# fake_method                                         StyleGAN3
# image_quality                                          Medium
# resolution                                          1024x1024
# confidence_score                                         0.88
# detection_difficulty                                   Medium
# dataset_split                                           train
# date_collected                                     2026-02-07
# version                                                  v2.0
# year                                                     2026
#
#                                                          6551  \
# image_id                                                 6552
# image_url             https://api.multiavatar.com/face995.jpg
# label                                                    FAKE
# label_numeric                                               0
# category                                         AI Generated
# gender                                                Unknown
# age_group                                                 50+
# source                                            MultiSource
# fake_method                                         StyleGAN3
# image_quality                                            High
# resolution                                          1024x1024
# confidence_score                                         0.83
# detection_difficulty                                   Medium
# dataset_split                                           train
# date_collected                                     2026-01-22
# version                                                  v2.0
# year                                                     2026
#
#                                                          6552  \
# image_id                                                 6553
# image_url             https://api.multiavatar.com/face996.jpg
# label                                                    FAKE
# label_numeric                                               0
# category                                         AI Generated
# gender                                                Unknown
# age_group                                               18-25
# source                                            MultiSource
# fake_method                                         StyleGAN3
# image_quality                                            High
# resolution                                          1024x1024
# confidence_score                                         0.85
# detection_difficulty                                     Hard
# dataset_split                                           train
# date_collected                                     2026-01-12
# version                                                  v2.0
# year                                                     2026
#
#                                                          6553  \
# image_id                                                 6554
# image_url             https://api.multiavatar.com/face997.jpg
# label                                                    FAKE
# label_numeric                                               0
# category                                         AI Generated
# gender                                                Unknown
# age_group                                                 50+
# source                                            MultiSource
# fake_method                                         StyleGAN3
# image_quality                                            High
# resolution                                          1024x1024
# confidence_score                                         0.96
# detection_difficulty                                     Hard
# dataset_split                                           train
# date_collected                                     2026-01-07
# version                                                  v2.0
# year                                                     2026
#
#                                                          6554  \
# image_id                                                 6555
# image_url             https://api.multiavatar.com/face998.jpg
# label                                                    FAKE
# label_numeric                                               0
# category                                         AI Generated
# gender                                                Unknown
# age_group                                               18-25
# source                                            MultiSource
# fake_method                                         StyleGAN3
# image_quality                                            High
# resolution                                          1024x1024
# confidence_score                                         0.91
# detection_difficulty                                   Medium
# dataset_split                                           train
# date_collected                                     2026-04-24
# version                                                  v2.0
# year                                                     2026
#
#                                                          6555  \
# image_id                                                 6556
# image_url             https://api.multiavatar.com/face999.jpg
# label                                                    FAKE
# label_numeric                                               0
# category                                         AI Generated
# gender                                                Unknown
# age_group                                               26-35
# source                                            MultiSource
# fake_method                                         StyleGAN3
# image_quality                                            High
# resolution                                          1024x1024
# confidence_score                                         0.86
# detection_difficulty                                   Medium
# dataset_split                                           train
# date_collected                                     2026-01-24
# version                                                  v2.0
# year                                                     2026
#
#                                                           6556
# image_id                                                  6557
# image_url             https://api.multiavatar.com/face1000.jpg
# label                                                     FAKE
# label_numeric                                                0
# category                                          AI Generated
# gender                                                 Unknown
# age_group                                                36-50
# source                                             MultiSource
# fake_method                                          StyleGAN3
# image_quality                                           Medium
# resolution                                           1024x1024
# confidence_score                                          0.93
# detection_difficulty                                      Hard
# dataset_split                                              val
# date_collected                                      2026-03-12
# version                                                   v2.0
# year                                                      2026
#
# [17 rows x 6557 columns]

# %%
# Range + index
df.axes
# Out:
# [RangeIndex(start=0, stop=6557, step=1),
#  Index(['image_id', 'image_url', 'label', 'label_numeric', 'category', 'gender',
#         'age_group', 'source', 'fake_method', 'image_quality', 'resolution',
#         'confidence_score', 'detection_difficulty', 'dataset_split',
#         'date_collected', 'version', 'year'],
#        dtype='str')]

# %%
# empty or missing data -- NaN
df.isna()
# Out:
#       image_id  image_url  label  label_numeric  category  gender  age_group  \
# 0        False      False  False          False     False   False      False
# 1        False      False  False          False     False   False      False
# 2        False      False  False          False     False   False      False
# 3        False      False  False          False     False   False      False
# 4        False      False  False          False     False   False      False
# ...        ...        ...    ...            ...       ...     ...        ...
# 6552     False      False  False          False     False   False      False
# 6553     False      False  False          False     False   False      False
# 6554     False      False  False          False     False   False      False
# 6555     False      False  False          False     False   False      False
# 6556     False      False  False          False     False   False      False
#
#       source  fake_method  image_quality  resolution  confidence_score  \
# 0      False         True          False       False             False
# 1      False         True          False       False             False
# 2      False         True          False       False             False
# 3      False         True          False       False             False
# 4      False         True          False       False             False
# ...      ...          ...            ...         ...               ...
# 6552   False        False          False       False             False
# 6553   False        False          False       False             False
# 6554   False        False          False       False             False
# 6555   False        False          False       False             False
# 6556   False        False          False       False             False
#
#       detection_difficulty  dataset_split  date_collected  version   year
# 0                    False          False           False    False  False
# 1                    False          False           False    False  False
# 2                    False          False           False    False  False
# 3                    False          False           False    False  False
# 4                    False          False           False    False  False
# ...                    ...            ...             ...      ...    ...
# 6552                 False          False           False    False  False
# 6553                 False          False           False    False  False
# 6554                 False          False           False    False  False
# 6555                 False          False           False    False  False
# 6556                 False          False           False    False  False
#
# [6557 rows x 17 columns]

# %%
# Not NaN
df = df.notna()
df
# Out:
#       image_id  image_url  label  label_numeric  category  gender  age_group  \
# 0         True       True   True           True      True    True       True
# 1         True       True   True           True      True    True       True
# 2         True       True   True           True      True    True       True
# 3         True       True   True           True      True    True       True
# 4         True       True   True           True      True    True       True
# ...        ...        ...    ...            ...       ...     ...        ...
# 6552      True       True   True           True      True    True       True
# 6553      True       True   True           True      True    True       True
# 6554      True       True   True           True      True    True       True
# 6555      True       True   True           True      True    True       True
# 6556      True       True   True           True      True    True       True
#
#       source  fake_method  image_quality  resolution  confidence_score  \
# 0       True        False           True        True              True
# 1       True        False           True        True              True
# 2       True        False           True        True              True
# 3       True        False           True        True              True
# 4       True        False           True        True              True
# ...      ...          ...            ...         ...               ...
# 6552    True         True           True        True              True
# 6553    True         True           True        True              True
# 6554    True         True           True        True              True
# 6555    True         True           True        True              True
# 6556    True         True           True        True              True
#
#       detection_difficulty  dataset_split  date_collected  version  year
# 0                     True           True            True     True  True
# 1                     True           True            True     True  True
# 2                     True           True            True     True  True
# 3                     True           True            True     True  True
# 4                     True           True            True     True  True
# ...                    ...            ...             ...      ...   ...
# 6552                  True           True            True     True  True
# 6553                  True           True            True     True  True
# 6554                  True           True            True     True  True
# 6555                  True           True            True     True  True
# 6556                  True           True            True     True  True
#
# [6557 rows x 17 columns]

# %%
# Many function at the same time -- summary
df.describe()
# Out:
#        image_id image_url label label_numeric category gender age_group  \
# count      6557      6557  6557          6557     6557   6557      6557
# unique        1         1     1             1        1      1         1
# top        True      True  True          True     True   True      True
# freq       6557      6557  6557          6557     6557   6557      6557
#
#        source fake_method image_quality resolution confidence_score  \
# count    6557        6557          6557       6557             6557
# unique      1           2             1          1                1
# top      True        True          True       True             True
# freq     6557        3767          6557       6557             6557
#
#        detection_difficulty dataset_split date_collected version  year
# count                  6557          6557           6557    6557  6557
# unique                    1             1              1       1     1
# top                    True          True           True    True  True
# freq                   6557          6557           6557    6557  6557

# %%
# array info
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6557 entries, 0 to 6556
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   image_id              6557 non-null   bool
#  1   image_url             6557 non-null   bool
#  2   label                 6557 non-null   bool
#  3   label_numeric         6557 non-null   bool
#  4   category              6557 non-null   bool
#  5   gender                6557 non-null   bool
#  6   age_group             6557 non-null   bool
#  7   source                6557 non-null   bool
#  8   fake_method           6557 non-null   bool
#  9   image_quality         6557 non-null   bool
#  10  resolution            6557 non-null   bool
#  11  confidence_score      6557 non-null   bool
#  12  detection_difficulty  6557 non-null   bool
#  13  dataset_split         6557 non-null   bool
#  14  date_collected        6557 non-null   bool
#  15  version               6557 non-null   bool
#  16  year                  6557 non-null   bool
# dtypes: bool(17)
# memory usage: 109.0 KB

# %%
# the first 2 rows
df.head(2)
# Out:
#    image_id  image_url  label  label_numeric  category  gender  age_group  \
# 0      True       True   True           True      True    True       True
# 1      True       True   True           True      True    True       True
#
#    source  fake_method  image_quality  resolution  confidence_score  \
# 0    True        False           True        True              True
# 1    True        False           True        True              True
#
#    detection_difficulty  dataset_split  date_collected  version  year
# 0                  True           True            True     True  True
# 1                  True           True            True     True  True

# %%
# The last 2 rows
df.tail(2)
# Out:
#       image_id  image_url  label  label_numeric  category  gender  age_group  \
# 6555      True       True   True           True      True    True       True
# 6556      True       True   True           True      True    True       True
#
#       source  fake_method  image_quality  resolution  confidence_score  \
# 6555    True         True           True        True              True
# 6556    True         True           True        True              True
#
#       detection_difficulty  dataset_split  date_collected  version  year
# 6555                  True           True            True     True  True
# 6556                  True           True            True     True  True

# %%
# Selecting data
df['gender']
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 6552    True
# 6553    True
# 6554    True
# 6555    True
# 6556    True
# Name: gender, Length: 6557, dtype: bool

# %%
# Series
type(df['gender'])
# Out:
# pandas.Series

# %%
#
type(df[['gender']])
# Out:
# pandas.DataFrame

# %%
# 2 columns
df[['gender', 'category']]
# Out:
#       gender  category
# 0       True      True
# 1       True      True
# 2       True      True
# 3       True      True
# 4       True      True
# ...      ...       ...
# 6552    True      True
# 6553    True      True
# 6554    True      True
# 6555    True      True
# 6556    True      True
#
# [6557 rows x 2 columns]

# %%
#
df.isnull().sum()
# Out:
# image_id                0
# image_url               0
# label                   0
# label_numeric           0
# category                0
# gender                  0
# age_group               0
# source                  0
# fake_method             0
# image_quality           0
# resolution              0
# confidence_score        0
# detection_difficulty    0
# dataset_split           0
# date_collected          0
# version                 0
# year                    0
# dtype: int64

# %%
# Sorting default is descending
df.sort_values(by='age_group', ascending=False)
# Out:
#       image_id  image_url  label  label_numeric  category  gender  age_group  \
# 0         True       True   True           True      True    True       True
# 4368      True       True   True           True      True    True       True
# 4378      True       True   True           True      True    True       True
# 4377      True       True   True           True      True    True       True
# 4376      True       True   True           True      True    True       True
# ...        ...        ...    ...            ...       ...     ...        ...
# 2183      True       True   True           True      True    True       True
# 2182      True       True   True           True      True    True       True
# 2181      True       True   True           True      True    True       True
# 2180      True       True   True           True      True    True       True
# 6556      True       True   True           True      True    True       True
#
#       source  fake_method  image_quality  resolution  confidence_score  \
# 0       True        False           True        True              True
# 4368    True         True           True        True              True
# 4378    True         True           True        True              True
# 4377    True         True           True        True              True
# 4376    True         True           True        True              True
# ...      ...          ...            ...         ...               ...
# 2183    True        False           True        True              True
# 2182    True        False           True        True              True
# 2181    True        False           True        True              True
# 2180    True        False           True        True              True
# 6556    True         True           True        True              True
#
#       detection_difficulty  dataset_split  date_collected  version  year
# 0                     True           True            True     True  True
# 4368                  True           True            True     True  True
# 4378                  True           True            True     True  True
# 4377                  True           True            True     True  True
# 4376                  True           True            True     True  True
# ...                    ...            ...             ...      ...   ...
# 2183                  True           True            True     True  True
# 2182                  True           True            True     True  True
# 2181                  True           True            True     True  True
# 2180                  True           True            True     True  True
# 6556                  True           True            True     True  True
#
# [6557 rows x 17 columns]
