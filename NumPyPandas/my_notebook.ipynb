# %% [markdown]
# # Welcome to Jupyter

# %%
pip install numpy matplotbil
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotbil (from versions: none)
# ERROR: No matching distribution found for matplotbil

# %%
import numpy as np 
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
grid = np.zeros((10,10), dtype=int)
grid[1,2] =1
grid[2,3] =1
grid[3,1] =1
grid[3,2] =1
grid[3,3] =1

plt.imshow(grid, cmap='binary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 grid = np.zeros((10,10), dtype=int)
#       2 grid[1,2] =1
#       3 grid[2,3] =1
#       4 grid[3,1] =1
#
# NameError: name 'np' is not defined
